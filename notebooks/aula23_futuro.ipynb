# %% [markdown]
# # 🧭 Aula 23 — O Engenheiro Químico do Futuro**Disciplina:** IA Aplicada à Engenharia Química---## O perfil T-shapedUma árvore: a haste é a profundidade em Eng. Química (fundamentos); a copa é aamplitude em dados, IA e software. Com haste fraca tomba; sem copa não alcança o sol.

# %% [markdown]
# ## Dados do mercado- Vagas de EQ que pedem Python + ML cresceram ~300% em 5 anos (LinkedIn 2024)- Salário médio de EQ com competências de IA ≈ 40% maior (Glassdoor 2024)Tendências: bioengenharia, energia, materiais, Indústria 4.0 (gêmeos digitais).

# %% [markdown]
# ## 3.1 — Autoavaliação de Competências (Radar)

# %% [markdown]
# ### Passo 1: defina seu perfil (1-5)

# %%
# Edite os valores SEGUNDO sua autoavaliacao honestaperfil = {    'Fund. EQ':        3,    'Python/Dados':    3,    'ML/IA':           3,    'Controle/Otim.':  3,    'Soft Skills':     4,    'Dominio Industrial': 3,}print('Confianca:', {k: '5 - especialista' if v>=4 else ('3 - avançando' if v>=3 else '1 - iniciante') for k,v in perfil.items()})

# %% [markdown]
# ### Passo 2: plote seu radar (grafico de teia)

# %%
import numpy as np, matplotlib.pyplot as pltlabels=list(perfil.keys()); n=len(labels)ang=np.linspace(0,2*np.pi,n,endpoint=False).tolist(); ang+=ang[:1]v=list(perfil.values())+[perfil[labels[0]]]ax=plt.subplot(111,polar=True)ax.fill(ang,v,alpha=0.35); ax.plot(ang,v,lw=2.5)ax.set_xticks(ang[:-1]); ax.set_xticklabels(labels)ax.set_ylim(0,5)plt.title(f'Média = {np.mean(list(perfil.values())):.1f}/5')plt.show()

# %% [markdown]
# ### Passo 3: identifique forças e lacunas

# %%
forcas = {k:v for k,v in perfil.items() if v>=4}lacunas = {k:v for k,v in perfil.items() if v<=2}print('Forças:', forcas or 'nenhuma ainda')print('Lacunas:', lacunas or 'nenhuma')print()print('Pergunta: qual lacuna é a MAIS ESTRATÉGICA para fechar nos próximos 12 meses?')

# %% [markdown]
# ## 3.2 — Plano de Desenvolvimento de 12 Meses

# %% [markdown]
# ### Monte seu plano (comparando com o mercado)Preencha mentalmente / em markdown:1. 2 lacunas priorizadas (da autoavaliacao)2. Curso/trilha para cada (Coursera, Udemy, AWS, Azure)3. Projeto pratico (GitHub) para demonstrar4. Certificacao escolhida5. Cronograma com marcos mensais6. Metrica de progresso

# %% [markdown]
# ### Passo 4: cronograma de 12 meses (exemplo)

# %%
import pandas as pdmeses = ['M1','M2','M3','M4','M5','M6','M7','M8','M9','M10','M11','M12']plano = pd.DataFrame({'Mes':meses,    'Curso':['Python avancado']*3 + ['ML aplicado']*4 + ['MLops/cloud']*5,    'Projeto':['soft-sensor no GitHub']*6 + ['MPC assistido']*6,    'Certif':['']*8 + ['AWS/Mlflow']*4})print(plano)

# %% [markdown]
# ### Passo 5: carta para voce mesmo (daqui a 12 meses)

# %%
carta = """Hoje eu sei: [seus pontos atuais]Em 12 meses quero saber: [meta clara]Para isso vou: [acao especifica]"""print(carta)

# %% [markdown]
# > **Reflexao:** qual habito semanal (ex: 2h de Python/projeto) voce> consegue manter pelos proximos 12 meses? Meta especifica + mensuravel + revisao periodic.

# %% [markdown]
# ## Checklist do plano- [ ] 2 lacunas priorizadas- [ ] Curso/trilha identificado para cada- [ ] Projeto pratico (GitHub) para demonstrar- [ ] Certificacao escolhida- [ ] Cronograma com marcos mensais- [ ] Metrica de progresso definida
